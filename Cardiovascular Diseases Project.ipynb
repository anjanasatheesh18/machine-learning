# %% [markdown]
# # CARDIOVASCULAR DISEASES

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
# Successfully installed keras-2.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\anjana\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.49.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: packaging in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\anjana\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\anjana\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\anjana\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\anjana\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anjana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anjana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anjana\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\anjana\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %% [markdown]
# # LOADING DATA

# %%
#loading data
data = pd.read_csv("C:\\Users\\ANJANA\\Desktop\\heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# # DATA ANALYSIS

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='count'>

# %%
#Examaning a corelation matrix of all the features 
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %% [markdown]
# Examine the count plot of age.

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
#colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
    plt.show()
# Out:
# C:\Users\ANJANA\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Examine the kdeplot of time and age as they both are significant features.

# %%
sns.kdeplot(x=data["time"], y=data["age"], hue =data["DEATH_EVENT"], palette=cols)
# Out:
# <AxesSubplot:xlabel='time', ylabel='age'>

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# Steps involved in Data Preprocessing
#
# 1.Dropping the outliers based on data analysis
# 2.Assigning values to features as X and target as y
# 3.Perform the scaling of the features
# 4.Split test and training sets

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.265205e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  3.594301e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  3.713120e-18  1.001676 -0.576918 -0.480393
# diabetes                  299.0  1.113936e-16  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0  3.341808e-18  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0 -4.841909e-16  1.001676 -0.735688 -0.735688
# platelets                 299.0  1.009969e-16  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0 -2.227872e-18  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.627435e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -5.940993e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -3.861645e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.069379e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#looking at the scaled features
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df,palette = colours)
plt.xticks(rotation=90)
plt.show()

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7)

# %%
pip install talos
# Out:
# Collecting talos
#   Downloading talos-1.3-py3-none-any.whl (56 kB)
# Requirement already satisfied: requests in c:\users\anjana\anaconda3\lib\site-packages (from talos) (2.26.0)
# Requirement already satisfied: statsmodels>=0.11.0 in c:\users\anjana\anaconda3\lib\site-packages (from talos) (0.12.2)
# Collecting kerasplotlib
#   Downloading kerasplotlib-1.0-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: tensorflow>=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from talos) (2.10.0)
# Requirement already satisfied: pandas in c:\users\anjana\anaconda3\lib\site-packages (from talos) (1.3.4)
# Requirement already satisfied: tqdm in c:\users\anjana\anaconda3\lib\site-packages (from talos) (4.62.3)
# Collecting wrangle
#   Downloading wrangle-0.7.2-py3-none-any.whl (52 kB)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting astetik
#   Downloading astetik-1.13-py3-none-any.whl (5.4 MB)
# Requirement already satisfied: numpy in c:\users\anjana\anaconda3\lib\site-packages (from talos) (1.20.3)
# Collecting chances
#   Downloading chances-0.1.9.tar.gz (35 kB)
# Requirement already satisfied: scipy>=1.1 in c:\users\anjana\anaconda3\lib\site-packages (from statsmodels>=0.11.0->talos) (1.7.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\anjana\anaconda3\lib\site-packages (from statsmodels>=0.11.0->talos) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anjana\anaconda3\lib\site-packages (from pandas->talos) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anjana\anaconda3\lib\site-packages (from pandas->talos) (2021.3)
# Requirement already satisfied: six in c:\users\anjana\anaconda3\lib\site-packages (from patsy>=0.5->statsmodels>=0.11.0->talos) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (3.3.0)
# Requirement already satisfied: packaging in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (21.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (2.0.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (2.10.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (3.2.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (14.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (1.12.1)
# Requirement already satisfied: setuptools in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (58.0.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (0.27.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (22.9.24)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (1.1.2)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (1.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (3.10.0.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\anjana\anaconda3\lib\site-packages (from tensorflow>=2.0.0->talos) (1.49.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\anjana\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->talos) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (2.12.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\anjana\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (2.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\anjana\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\anjana\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\anjana\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\anjana\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anjana\anaconda3\lib\site-packages (from requests->talos) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anjana\anaconda3\lib\site-packages (from requests->talos) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from requests->talos) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anjana\anaconda3\lib\site-packages (from requests->talos) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=2.0.0->talos) (3.2.1)
# Collecting geonamescache
#   Downloading geonamescache-1.5.0-py3-none-any.whl (26.4 MB)
# Requirement already satisfied: IPython in c:\users\anjana\anaconda3\lib\site-packages (from astetik->talos) (7.29.0)
# Requirement already satisfied: seaborn in c:\users\anjana\anaconda3\lib\site-packages (from astetik->talos) (0.11.2)
# Requirement already satisfied: pygments in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (2.10.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (5.1.0)
# Requirement already satisfied: colorama in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (0.18.0)
# Requirement already satisfied: decorator in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (5.1.0)
# Requirement already satisfied: backcall in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\anjana\anaconda3\lib\site-packages (from IPython->astetik->talos) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\anjana\anaconda3\lib\site-packages (from jedi>=0.16->IPython->astetik->talos) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\anjana\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->astetik->talos) (0.2.5)
# Requirement already satisfied: matplotlib in c:\users\anjana\anaconda3\lib\site-packages (from kerasplotlib->talos) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anjana\anaconda3\lib\site-packages (from matplotlib->kerasplotlib->talos) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anjana\anaconda3\lib\site-packages (from matplotlib->kerasplotlib->talos) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anjana\anaconda3\lib\site-packages (from matplotlib->kerasplotlib->talos) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anjana\anaconda3\lib\site-packages (from matplotlib->kerasplotlib->talos) (3.0.4)
# Requirement already satisfied: scikit-learn in c:\users\anjana\anaconda3\lib\site-packages (from sklearn->talos) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anjana\anaconda3\lib\site-packages (from scikit-learn->sklearn->talos) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\anjana\anaconda3\lib\site-packages (from scikit-learn->sklearn->talos) (1.1.0)
# Building wheels for collected packages: chances, sklearn
#   Building wheel for chances (setup.py): started
#   Building wheel for chances (setup.py): finished with status 'done'
#   Created wheel for chances: filename=chances-0.1.9-py3-none-any.whl size=41609 sha256=6bbf4ea7786f50a8d8568307f7438b1c0a49a47d964d2f5b089aca8e9ecbe9c9
#   Stored in directory: c:\users\anjana\appdata\local\pip\cache\wheels\c3\26\2b\8ae098b8e9dd7cc1fd0a9131c0f1efea60d710ff7906bf0ab4
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=f16f1e70f0da29b16a528ce83dc7ca17c2381840fd527d2896f458bcd31fcc74
#   Stored in directory: c:\users\anjana\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built chances sklearn
# Installing collected packages: sklearn, wrangle, geonamescache, kerasplotlib, chances, astetik, talos
# Successfully installed astetik-1.13 chances-0.1.9 geonamescache-1.5.0 kerasplotlib-1.0 sklearn-0.0 talos-1.3 wrangle-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# # 1. SUPPORT VECTOR MACHINE (SVM)

# %%
from sklearn import svm 
# Instantiating the SVM algorithm 
model1=svm.SVC()

# Fitting the model 
model1.fit (X_train, y_train)

# Predicting the test variables
y_pred = model1.predict(X_test)

# Getting the score 
model1.score (X_test, y_test)
# Out:
# 0.8933333333333333

# %%
# Printing classification report (since there was biasness in target labels)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93        57
#            1       0.86      0.67      0.75        18
#
#     accuracy                           0.89        75
#    macro avg       0.88      0.82      0.84        75
# weighted avg       0.89      0.89      0.89        75

# %%
# Getting the confusion matrix
cmap1 = sns.diverging_palette(2, 165, s=80, l=55, n=9)
plt.subplots(figsize=(10,7))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':25})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2. Artificial Neural Network (ANN)

# %% [markdown]
# Here, build an artificial neural network.
#
# Following steps are involved in the model building
#
# 1.Initialising the ANN
# 2.Defining by adding layers
# 3.Compiling the ANN
# 4.Train the ANN

# %%
import talos
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from tensorflow.keras.optimizers import Adam,Nadam, SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 47ms/step - loss: 0.6929 - accuracy: 0.6425 - val_loss: 0.6922 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6919 - accuracy: 0.6480 - val_loss: 0.6913 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6911 - accuracy: 0.6480 - val_loss: 0.6904 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.
500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4682 - accuracy: 0.8380 - val_loss: 0.4581 - val_accuracy: 0.8444
# Epoch 51/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4655 - accuracy: 0.8492 - val_loss: 0.4566 - val_accuracy: 0.8444
# Epoch 52/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4605 - accuracy: 0.8045 - val_loss: 0.4553 - val_accuracy: 0.8444
# Epoch 53/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4369 - accuracy: 0.8156 - val_loss: 0.4543 - val_accuracy: 0.8444
# Epoch 54/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4339 - accuracy: 0.7821 - val_loss: 0.4528 - val_accuracy: 0.8222
# Epoch 55/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4649 - accuracy: 0.7542 - val_loss: 0.4535 - val_accuracy: 0.8222
# Epoch 56/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4482 - accuracy: 0.7933 - val_loss: 0.4528 - val_accuracy: 0.8222
# Epoch 57/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4766 - accuracy: 0.7933 - val_loss: 0.4520 - val_accuracy: 0.8222
# Epoch 58/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4817 - accuracy: 0.8045 - val_loss: 0.4510 - val_accuracy: 0.8444
# Epoch 59/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4517 - accuracy: 0.8045 - val_loss: 0.4493 - val_accuracy: 0.8444
# Epoch 60/500
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4583 - accuracy: 0.8101 - val_loss: 0.4475 - val_accuracy: 0.8444
# Epoch 61/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4705 - accuracy: 0.7877 - val_loss: 0.4479 - val_accuracy: 0.8444
# Epoch 62/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4563 - accuracy: 0.8212 - val_loss: 0.4484 - val_accuracy: 0.8444
# Epoch 63/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4512 - accuracy: 0.7989 - val_loss: 0.4483 - val_accuracy: 0.8444
# Epoch 64/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4785 - accuracy: 0.8324 - val_loss: 0.4483 - val_accuracy: 0.8444
# Epoch 65/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4739 - accuracy: 0.8101 - val_loss: 0.4483 - val_accuracy: 0.8444
# Epoch 66/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4511 - accuracy: 0.8268 - val_loss: 0.4486 - val_accuracy: 0.8444
# Epoch 67/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4172 - accuracy: 0.8045 - val_loss: 0.4491 - val_accuracy: 0.8444
# Epoch 68/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4080 - accuracy: 0.8212 - val_loss: 0.4507 - val_accuracy: 0.8222
# Epoch 69/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4579 - accuracy: 0.8380 - val_loss: 0.4503 - val_accuracy: 0.8444
# Epoch 70/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4752 - accuracy: 0.8156 - val_loss: 0.4510 - val_accuracy: 0.8444
# Epoch 71/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4678 - accuracy: 0.8156 - val_loss: 0.4515 - val_accuracy: 0.8444
# Epoch 72/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4512 - accuracy: 0.8268 - val_loss: 0.4523 - val_accuracy: 0.8444
# Epoch 73/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4403 - accuracy: 0.8268 - val_loss: 0.4527 - val_accuracy: 0.8222
# Epoch 74/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4339 - accuracy: 0.8268 - val_loss: 0.4518 - val_accuracy: 0.8222
# Epoch 75/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4586 - accuracy: 0.8324 - val_loss: 0.4504 - val_accuracy: 0.8222
# Epoch 76/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4500 - accuracy: 0.8436 - val_loss: 0.4487 - val_accuracy: 0.8222
# Epoch 77/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4962 - accuracy: 0.8101 - val_loss: 0.4485 - val_accuracy: 0.8222
# Epoch 78/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3821 - accuracy: 0.8659 - val_loss: 0.4490 - val_accuracy: 0.8222
# Epoch 79/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3989 - accuracy: 0.8268 - val_loss: 0.4483 - val_accuracy: 0.8222
# Epoch 80/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4645 - accuracy: 0.8212 - val_loss: 0.4476 - val_accuracy: 0.8000

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 75.47%

# %% [markdown]
# Plotting training and validation loss over epochs

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# Plotting training and validation accuracy over epochs

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Concluding the model with:
#
# Testing on the test set
# Evaluating the confusion matrix
# Evaluating the classification report

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        57
#            1       0.61      0.61      0.61        18
#
#     accuracy                           0.81        75
#    macro avg       0.74      0.74      0.74        75
# weighted avg       0.81      0.81      0.81        75
